# %%
def add(a,b):
    return a*b
print(add(2,3))
# Out:
# 6

# %%
def add1(a,b):
    return a*b
x=add1(2,3)
print(x)
# Out:
# 6

# %%
def print_twice(x):
    print(x)
    print(x)
print_twice("hello")
# Out:
# hello
# hello

# %%
def multiply_by_two(x):
    return x*2
my_list=[1,2,3,4]
result=map(multiply_by_two,my_list)
print(list(result))
# Out:
# [2, 4, 6, 8]

# %%
x=10 # global variable
def my_func():
    x=5 # local variable
    print(x)
my_func()
print(x) # global variable print
print(my_func())
# Out:
# 5
# 10
# 5
# None

# %%
x=5
def my_func():
    global x

    x=10
my_func()
print(x)
# Out:
# 10

# %%
x=5
def my_func():
    global x
    x=x+1
print(x)
my_func()
print(x)
# Out:
# 5
# 6

# %%
x=5
def my_func():
    x=10
    print(x)
my_func()
print(x)
# Out:
# 10
# 5

# %%
def my(x,y=5):
    return x+y
print(my(2))
print(my(2,3))
# Out:
# 7
# 5

# %%
x=10
def my():
    global x
    x+=5
    print(x)
my()
print(x)
# Out:
# 15
# 15

# %%
def my(x):
    x[0]=5
mylist=[1,2,3]
my(mylist)
print(mylist)
# Out:
# [5, 2, 3]

# %%
def my(a,b):
    return a+b , a-b
result=my(3,2)
print(result[0])
# Out:
# 5

# %%
def my(a,b=2,c=3):
    print(a,b,c)
my(1,c=4)
# Out:
# 1 2 4

# %%
def my(a=1,b=2,c=2):
    print(a,b,c)
my(c=4)
# Out:
# 1 2 4

# %%
def my(a,b):
    a=b
x=1
y=2
my(x,y)
print(x,y)
# Out:
# 1 2
